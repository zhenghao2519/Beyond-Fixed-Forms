# %%
BASE_CLASSES_SCANNET200 = [
    "chair",
    "table",
    "door",
    "couch",
    "cabinet",
    "shelf",
    "desk",
    "office chair",
    "bed",
    "sink",
    "picture",
    "window",
    "toilet",
    "bookshelf",
    "curtain",
    "armchair",
    "coffee table",
    "refrigerator",
    "kitchen cabinet",
    "counter",
    "dresser",
    "ceiling",
    "bathtub",
    "end table",
    "dining table",
    "shower curtain",
    "closet",
    "ottoman",
    "bench",
    "sofa chair",
    "file cabinet",
    "blinds",
    "container",
    "wardrobe",
    "seat",
    "column",
    "shower wall",
    "kitchen counter",
    "mini fridge",
    "shower door",
    "pillar",
    "furniture",
    "storage container",
    "closet door",
    "shower floor",
    "bathroom counter",
    "closet wall",
    "bathroom stall door",
    "bathroom cabinet",
    "folded chair",
    "mattress",
]

NOVEL_CLASSES_SCANNET200 = [
    "pillow",
    "monitor",
    "book",
    "box",
    "lamp",
    "towel",
    "clothes",
    "tv",
    "nightstand",
    "stool",
    "cushion",
    "plant",
    "keyboard",
    "bag",
    "backpack",
    "toilet paper",
    "printer",
    "tv stand",
    "whiteboard",
    "blanket",
    "trash can",
    "stairs",
    "microwave",
    "stove",
    "shoe",
    "computer tower",
    "bottle",
    "bin",
    "board",
    "washing machine",
    "mirror",
    "copier",
    "basket",
    "fan",
    "laptop",
    "shower",
    "paper",
    "person",
    "paper towel dispenser",
    "oven",
    "rack",
    "plate",
    "blackboard",
    "piano",
    "suitcase",
    "rail",
    "radiator",
    "recycling bin",
    "soap dispenser",
    "telephone",
    "bucket",
    "clock",
    "stand",
    "light",
    "laundry basket",
    "pipe",
    "clothes dryer",
    "guitar",
    "toilet paper holder",
    "speaker",
    "bicycle",
    "ladder",
    "bathroom stall",
    "cup",
    "jacket",
    "storage bin",
    "coffee maker",
    "dishwasher",
    "paper towel roll",
    "machine",
    "mat",
    "windowsill",
    "bar",
    "toaster",
    "bulletin board",
    "ironing board",
    "fireplace",
    "soap dish",
    "doorframe",
    "toilet paper dispenser",
    "fire extinguisher",
    "ball",
    "hat",
    "shower curtain rod",
    "water cooler",
    "paper cutter",
    "tray",
    "ledge",
    "toaster oven",
    "mouse",
    "toilet seat cover dispenser",
    "cart",
    "scale",
    "tissue box",
    "light switch",
    "crate",
    "power outlet",
    "decoration",
    "sign",
    "projector",
    "vacuum cleaner",
    "candle",
    "plunger",
    "stuffed animal",
    "headphones",
    "dish rack",
    "broom",
    "guitar case",
    "range hood",
    "dustpan",
    "hair dryer",
    "water bottle",
    "handicap bar",
    "purse",
    "vent",
    "water pitcher",
    "mailbox",
    "bowl",
    "paper bag",
    "alarm clock",
    "music stand",
    "projector screen",
    "divider",
    "laundry detergent",
    "object",
    "bathroom vanity",
    "laundry hamper",
    "ceiling light",
    "trash bin",
    "dumbbell",
    "stair rail",
    "tube",
    "cd case",
    "closet rod",
    "coffee kettle",
    "structure",
    "shower head",
    "keyboard piano",
    "case of water bottles",
    "coat rack",
    "storage organizer",
    "fire alarm",
    "power strip",
    "calendar",
    "poster",
    "potted plant",
    "luggage",
]

INSTANCE_CAT_SCANNET_200 = [
    "chair",
    "table",
    "door",
    "couch",
    "cabinet",
    "shelf",
    "desk",
    "office chair",
    "bed",
    "pillow",
    "sink",
    "picture",
    "window",
    "toilet",
    "bookshelf",
    "monitor",
    "curtain",
    "book",
    "armchair",
    "coffee table",
    "box",
    "refrigerator",
    "lamp",
    "kitchen cabinet",
    "towel",
    "clothes",
    "tv",
    "nightstand",
    "counter",
    "dresser",
    "stool",
    "cushion",
    "plant",
    "ceiling",
    "bathtub",
    "end table",
    "dining table",
    "keyboard",
    "bag",
    "backpack",
    "toilet paper",
    "printer",
    "tv stand",
    "whiteboard",
    "blanket",
    "shower curtain",
    "trash can",
    "closet",
    "stairs",
    "microwave",
    "stove",
    "shoe",
    "computer tower",
    "bottle",
    "bin",
    "ottoman",
    "bench",
    "board",
    "washing machine",
    "mirror",
    "copier",
    "basket",
    "sofa chair",
    "file cabinet",
    "fan",
    "laptop",
    "shower",
    "paper",
    "person",
    "paper towel dispenser",
    "oven",
    "blinds",
    "rack",
    "plate",
    "blackboard",
    "piano",
    "suitcase",
    "rail",
    "radiator",
    "recycling bin",
    "container",
    "wardrobe",
    "soap dispenser",
    "telephone",
    "bucket",
    "clock",
    "stand",
    "light",
    "laundry basket",
    "pipe",
    "clothes dryer",
    "guitar",
    "toilet paper holder",
    "seat",
    "speaker",
    "column",
    "bicycle",
    "ladder",
    "bathroom stall",
    "shower wall",
    "cup",
    "jacket",
    "storage bin",
    "coffee maker",
    "dishwasher",
    "paper towel roll",
    "machine",
    "mat",
    "windowsill",
    "bar",
    "toaster",
    "bulletin board",
    "ironing board",
    "fireplace",
    "soap dish",
    "kitchen counter",
    "doorframe",
    "toilet paper dispenser",
    "mini fridge",
    "fire extinguisher",
    "ball",
    "hat",
    "shower curtain rod",
    "water cooler",
    "paper cutter",
    "tray",
    "shower door",
    "pillar",
    "ledge",
    "toaster oven",
    "mouse",
    "toilet seat cover dispenser",
    "furniture",
    "cart",
    "storage container",
    "scale",
    "tissue box",
    "light switch",
    "crate",
    "power outlet",
    "decoration",
    "sign",
    "projector",
    "closet door",
    "vacuum cleaner",
    "candle",
    "plunger",
    "stuffed animal",
    "headphones",
    "dish rack",
    "broom",
    "guitar case",
    "range hood",
    "dustpan",
    "hair dryer",
    "water bottle",
    "handicap bar",
    "purse",
    "vent",
    "shower floor",
    "water pitcher",
    "mailbox",
    "bowl",
    "paper bag",
    "alarm clock",
    "music stand",
    "projector screen",
    "divider",
    "laundry detergent",
    "bathroom counter",
    "object",
    "bathroom vanity",
    "closet wall",
    "laundry hamper",
    "bathroom stall door",
    "ceiling light",
    "trash bin",
    "dumbbell",
    "stair rail",
    "tube",
    "bathroom cabinet",
    "cd case",
    "closet rod",
    "coffee kettle",
    "structure",
    "shower head",
    "keyboard piano",
    "case of water bottles",
    "coat rack",
    "storage organizer",
    "folded chair",
    "fire alarm",
    "power strip",
    "calendar",
    "poster",
    "potted plant",
    "luggage",
    "mattress",
]

HEAD_CATS_SCANNET_200 = [ # wall and floor removed
    "tv stand",
    "curtain",
    "blinds",
    "shower curtain",
    "bookshelf",
    "tv",
    "kitchen cabinet",
    "pillow",
    "lamp",
    "dresser",
    "monitor",
    "object",
    "ceiling",
    "board",
    "stove",
    "closet wall",
    "couch",
    "office chair",
    "kitchen counter",
    "shower",
    "closet",
    "doorframe",
    "sofa chair",
    "mailbox",
    "nightstand",
    "washing machine",
    "picture",
    "book",
    "sink",
    "recycling bin",
    "table",
    "backpack",
    "shower wall",
    "toilet",
    "copier",
    "counter",
    "stool",
    "refrigerator",
    "window",
    "file cabinet",
    "chair",
    "plant",
    "coffee table",
    "stairs",
    "armchair",
    "cabinet",
    "bathroom vanity",
    "bathroom stall",
    "mirror",
    "blackboard",
    "trash can",
    "stair rail",
    "box",
    "towel",
    "door",
    "clothes",
    "whiteboard",
    "bed",
    "bathtub",
    "desk",
    "wardrobe",
    "clothes dryer",
    "radiator",
    "shelf",
]
COMMON_CATS_SCANNET_200 = [
    "cushion",
    "end table",
    "dining table",
    "keyboard",
    "bag",
    "toilet paper",
    "printer",
    "blanket",
    "microwave",
    "shoe",
    "computer tower",
    "bottle",
    "bin",
    "ottoman",
    "bench",
    "basket",
    "fan",
    "laptop",
    "person",
    "paper towel dispenser",
    "oven",
    "rack",
    "piano",
    "suitcase",
    "rail",
    "container",
    "telephone",
    "stand",
    "light",
    "laundry basket",
    "pipe",
    "seat",
    "column",
    "bicycle",
    "ladder",
    "jacket",
    "storage bin",
    "coffee maker",
    "dishwasher",
    "machine",
    "mat",
    "windowsill",
    "bulletin board",
    "fireplace",
    "mini fridge",
    "water cooler",
    "shower door",
    "pillar",
    "ledge",
    "furniture",
    "cart",
    "decoration",
    "closet door",
    "vacuum cleaner",
    "dish rack",
    "range hood",
    "projector screen",
    "divider",
    "bathroom counter",
    "laundry hamper",
    "bathroom stall door",
    "ceiling light",
    "trash bin",
    "bathroom cabinet",
    "structure",
    "storage organizer",
    "potted plant",
    "mattress",
]
TAIL_CATS_SCANNET_200 = [
    "paper",
    "plate",
    "soap dispenser",
    "bucket",
    "clock",
    "guitar",
    "toilet paper holder",
    "speaker",
    "cup",
    "paper towel roll",
    "bar",
    "toaster",
    "ironing board",
    "soap dish",
    "toilet paper dispenser",
    "fire extinguisher",
    "ball",
    "hat",
    "shower curtain rod",
    "paper cutter",
    "tray",
    "toaster oven",
    "mouse",
    "toilet seat cover dispenser",
    "storage container",
    "scale",
    "tissue box",
    "light switch",
    "crate",
    "power outlet",
    "sign",
    "projector",
    "candle",
    "plunger",
    "stuffed animal",
    "headphones",
    "broom",
    "guitar case",
    "dustpan",
    "hair dryer",
    "water bottle",
    "handicap bar",
    "purse",
    "vent",
    "shower floor",
    "water pitcher",
    "bowl",
    "paper bag",
    "alarm clock",
    "music stand",
    "laundry detergent",
    "dumbbell",
    "tube",
    "cd case",
    "closet rod",
    "coffee kettle",
    "shower head",
    "keyboard piano",
    "case of water bottles",
    "coat rack",
    "folded chair",
    "fire alarm",
    "power strip",
    "calendar",
    "poster",
    "luggage",
]

# %%
import pandas as pd
import numpy as np
import sys

# # remove the comma at end of each line
file_path = 'stage1_new_refine_overall_results.csv'
# file_path = "/home/jie_zhenghao/Beyond-Fixed-Forms/evaluation/eval_results/for_comparision/open3dis_hct_result_00_142.csv"
with open(file_path, "r") as f:
    lines = f.readlines()
with open(file_path, "w") as f:
    for line in lines:
        if line.strip("\n")[-1] == ",":
            f.write(line.strip("\n")[:-1] + "\n")
        else:
            f.write(line)

# Load the overall_results.csv file
df = pd.read_csv(file_path)

# %%
df.keys()
df
# Out:
#               class        ap      ap50      ap25        rc      rc50  \
# 0          tv stand  0.473367  0.501280  0.501379  0.944444  1.000000
# 1           curtain  0.347057  0.429915  0.498103  0.675926  0.833333
# 2            blinds  0.000000  0.000000  0.250904  0.000000  0.000000
# 3    shower curtain  0.434474  0.511811  0.512793  0.851852  1.000000
# 4         bookshelf  0.250350  0.392011  0.498072  0.492593  0.766667
# ..              ...       ...       ...       ...       ...       ...
# 123            vent       NaN       NaN       NaN       NaN       NaN
# 124    shower floor  0.502050  0.502203  0.502525  1.000000  1.000000
# 125   water pitcher  0.391684  0.503650  0.504032  0.777778  1.000000
# 126     alarm clock       NaN       NaN       NaN       NaN       NaN
# 127     music stand       NaN       NaN       NaN       NaN       NaN
#
#          rc25
# 0    1.000000
# 1    0.958333
# 2    0.500000
# 3    1.000000
# 4    0.966667
# ..        ...
# 123       NaN
# ...

# %%
print(df['class'][0])
print(df['ap'][0])
print(df['ap50'][0])
print(df['ap25'][0])
print(len(df['class']))
# print("power outlet" in TAIL_CATS_SCANNET_200)
# df['class id'].keys()[89], df['class id'].keys()[89] in (TAIL_CATS_SCANNET_200)
# Out:
# tv stand
# 0.4733672449898606
# 0.501280409731114
# 0.5013793103448276
# 128

# %%
np.asarray(df['ap'])
# Out:
# array([0.47336724, 0.34705693, 0.        , 0.43447421, 0.2503502 ,
#        0.4461637 , 0.3019228 , 0.37105148, 0.3743803 , 0.29540849,
#        0.4057633 , 0.07019183, 0.28654528, 0.07831027, 0.16188861,
#        0.09279816, 0.37728334, 0.48358403, 0.30174186, 0.        ,
#        0.02784603, 0.16630077, 0.4623589 , 0.31891993, 0.29545561,
#        0.30466294, 0.16136074, 0.0150083 , 0.35818211, 0.38709598,
#        0.35978394, 0.38632711, 0.27044919, 0.50869185, 0.51091159,
#        0.14332474, 0.41787654, 0.45638098, 0.28274846, 0.3727716 ,
#        0.        , 0.28546214, 0.        , 0.40308503, 0.3559668 ,
#        0.32008429, 0.47768104, 0.18967163, 0.38141314, 0.26643463,
#        0.1325353 , 0.39682144, 0.16680622, 0.36795881, 0.20776508,
#               nan, 0.33211995, 0.32099196, 0.09268026, 0.47052303,
#        0.39113808, 0.16785633, 0.44638099, 0.39723615, 0.22861393,
#        0.16751376, 0.30058856, 0.        , 0.30253118, 0.42842626,
# ...

# %%
# Calculate the mean average precision (mAP)
# mAP = np.nanmean(df['ap'])
# mAP50 = np.nanmean(df['ap50'])
# mAP25 = np.nanmean(df['ap25']) 
# mRC = np.nanmean(df['rc'])
# mRC_50 = np.nanmean(df['rc50'])
# mRC_25 = np.nanmean(df['rc25'])

# Calculate the mean average precision (mAP) for the common classes
# choose the common classes

# check if the class id is in the common classes
common_classes = df[df['class'].isin(COMMON_CATS_SCANNET_200)]
# print(common_classes)
mAP_common_classes = np.nanmean(common_classes['ap'])
mAP50_common_classes = np.nanmean(common_classes['ap50'])
mAP25_common_classes = np.nanmean(common_classes['ap25'])
mRC_common_classes = np.nanmean(common_classes['rc'])
mRC50_common_classes = np.nanmean(common_classes['rc50'])
mRC25_common_classes = np.nanmean(common_classes['rc25'])
# Calculate the mean average precision (mAP) for the head classes
head_classes = df[df['class'].isin(HEAD_CATS_SCANNET_200)]
mAP_head_classes = np.nanmean(head_classes['ap'])
mAP50_head_classes = np.nanmean(head_classes['ap50'])
mAP25_head_classes = np.nanmean(head_classes['ap25'])
mRC_head_classes = np.nanmean(head_classes['rc'])
mRC50_head_classes = np.nanmean(head_classes['rc50'])
mRC25_head_classes = np.nanmean(head_classes['rc25'])

# Calculate the mean average precision (mAP) for the tail classes
tail_classes = df[df['class'].isin(TAIL_CATS_SCANNET_200)]
mAP_tail_classes = np.nanmean(tail_classes['ap'])
mAP50_tail_classes = np.nanmean(tail_classes['ap50'])
mAP25_tail_classes = np.nanmean(tail_classes['ap25'])
mRC_tail_classes = np.nanmean(tail_classes['rc'])
mRC50_tail_classes = np.nanmean(tail_classes['rc50'])
mRC25_tail_classes = np.nanmean(tail_classes['rc25'])

current_classes = pd.concat([head_classes, tail_classes, common_classes])

# Calculate the mean average precision (mAP) for the base classes
base_classes = current_classes[current_classes['class'].isin(BASE_CLASSES_SCANNET200)]
mAP_base_classes = np.nanmean(base_classes['ap'])
mAP50_base_classes = np.nanmean(base_classes['ap50'])
mAP25_base_classes = np.nanmean(base_classes['ap25'])
mRC_base_classes = np.nanmean(base_classes['rc'])
mRC50_base_classes = np.nanmean(base_classes['rc50'])
mRC25_base_classes = np.nanmean(base_classes['rc25'])

# Calculate the mean average precision (mAP) for the novel classes
novel_classes = current_classes[current_classes['class'].isin(NOVEL_CLASSES_SCANNET200)]
mAP_novel_classes = np.nanmean(novel_classes['ap'])
mAP50_novel_classes = np.nanmean(novel_classes['ap50'])
mAP25_novel_classes = np.nanmean(novel_classes['ap25'])
mRC_novel_classes = np.nanmean(novel_classes['rc'])
mRC50_novel_classes = np.nanmean(novel_classes['rc50'])
mRC25_novel_classes = np.nanmean(novel_classes['rc25'])

# Calculate the mean average precision (mAP) for the current classes
mAP = np.nanmean(current_classes['ap'])
mAP50 = np.nanmean(current_classes['ap50'])
mAP25 = np.nanmean(current_classes['ap25'])
mRC = np.nanmean(current_classes['rc'])
mRC_50 = np.nanmean(current_classes['rc50'])
mRC_25 = np.nanmean(current_classes['rc25'])

print("number of each class", len(common_classes), len(head_classes), len(tail_classes), len(base_classes), len(novel_classes))
print(f"classes", f"  mAP   ", f"   mAP50   ", f"   mAP25  ", f"   mRC  ", f"   mRC50  ", f"   mRC25  ")
print(f'all    ', mAP, mAP50, mAP25, mRC, mRC_50, mRC_25)
print(f'head   ', mAP_head_classes, mAP50_head_classes, mAP25_head_classes, mRC_head_classes, mRC50_head_classes, mRC25_head_classes)
print(f'common ', mAP_common_classes, mAP50_common_classes, mAP25_common_classes, mRC_common_classes, mRC50_common_classes, mRC25_common_classes)
print(f'tail   ', mAP_tail_classes, mAP50_tail_classes, mAP25_tail_classes, mRC_tail_classes, mRC50_tail_classes, mRC25_tail_classes)
print(f'------------------------------------------------------------------------')
print(f'base   ', mAP_base_classes, mAP50_base_classes, mAP25_base_classes, mRC_base_classes, mRC50_base_classes, mRC25_base_classes)
print(f'novel  ', mAP_novel_classes, mAP50_novel_classes, mAP25_novel_classes, mRC_novel_classes, mRC50_novel_classes, mRC25_novel_classes)
# Out:
# number of each class 40 40 48 31 97
# classes   mAP       mAP50       mAP25      mRC      mRC50      mRC25
# all     0.27869482266261236 0.33720525103350135 0.3988740498769856 0.5443215439866821 0.6564785260949939 0.774691114343288
# head    0.2939684831497786 0.3653083531620089 0.4204467016502768 0.5699801392465726 0.7055984611620418 0.8083863025820023
# common  0.2691768136544289 0.3196291523847951 0.3855515359259178 0.5269484287458144 0.6231177628236452 0.7502756587315411
# tail    0.271506486935283 0.32404390561299645 0.3885970205785927 0.533667695473251 0.6361882716049383 0.7623456790123456
# ------------------------------------------------------------------------
# base    0.28534460556276614 0.3509385394537684 0.43421623551411787 0.5574126304461852 0.683087779482888 0.8433160686956819
# novel   0.27629128667460506 0.33224141184545297 0.38609976591175704 0.5395898259892713 0.6468607236656346 0.749886913974953

# %%
class_order = df['class']
class_order
# Out:
# 0            tv stand
# 1             curtain
# 2              blinds
# 3      shower curtain
# 4           bookshelf
#             ...
# 123              vent
# 124      shower floor
# 125     water pitcher
# 126       alarm clock
# 127       music stand
# Name: class, Length: 128, dtype: object

# %%
# Load the overall_results.csv file
df = pd.read_csv('/home/jie_zhenghao/Beyond-Fixed-Forms/evaluation/eval_results/for_comparision/ordered_open3dis_result.csv')
open3dis_class_num = 30
print(df['class'].count())
# Out:
# 198

# %%
"""order open3dis results into HEAD, COMMON, TAIL order"""
# head_classes = df[df['class'].isin(HEAD_CATS_SCANNET_200)]
# head_classes
# ordered_head_classes = []
# # make head classes in the same order like HEAD_CATS_SCANNET_200
# for i in range(len(HEAD_CATS_SCANNET_200)):
#     if HEAD_CATS_SCANNET_200[i] in head_classes['class'].values:
#         ordered_head_classes.append(head_classes[head_classes['class'] == HEAD_CATS_SCANNET_200[i]])
# ordered_head_classes = pd.concat(ordered_head_classes)
# ordered_head_classes
        

# common_classes = df[df['class'].isin(COMMON_CATS_SCANNET_200)]
# common_classes
# ordered_common_classes = []
# # make head classes in the same order like HEAD_CATS_SCANNET_200
# for i in range(len(COMMON_CATS_SCANNET_200)):
#     if COMMON_CATS_SCANNET_200[i] in common_classes['class'].values:
#         ordered_common_classes.append(common_classes[common_classes['class'] == COMMON_CATS_SCANNET_200[i]])
# ordered_common_classes = pd.concat(ordered_common_classes)
# ordered_common_classes

# tail_classes = df[df['class'].isin(TAIL_CATS_SCANNET_200)]
# tail_classes
# ordered_tail_classes = []
# # make head classes in the same order like HEAD_CATS_SCANNET_200
# for i in range(len(TAIL_CATS_SCANNET_200)):
#     if TAIL_CATS_SCANNET_200[i] in tail_classes['class'].values:
#         ordered_tail_classes.append(tail_classes[tail_classes['class'] == TAIL_CATS_SCANNET_200[i]])
# ordered_tail_classes = pd.concat(ordered_tail_classes)
# ordered_tail_classes

# ordered_classes = pd.concat([ordered_head_classes, ordered_tail_classes, ordered_common_classes])

# # replace nan values with -1
# ordered_classes = ordered_classes.fillna(-1)

# # save the ordered classes to a csv file, which also contains nan values
# ordered_classes.to_csv('ordered_classes.csv', index=False)
# Out:
# 'order open3dis results into HEAD, COMMON, TAIL order'

# %%
print(df['class'][0])
print(df['ap'][0])
print(df['ap50'][0])
print(df['ap25'][0])
print(len(df['class']))
# Out:
# tv stand
# 0.4752062851765852
# 0.5034013605442177
# 0.5035211267605634
# 198

# %%
# Calculate the mean average precision (mAP)
# mAP = np.nanmean(df['ap'])
# mAP50 = np.nanmean(df['ap50'])
# mAP25 = np.nanmean(df['ap25']) 
# mRC = np.nanmean(df['rc'])
# mRC50 = np.nanmean(df['rc50'])
# mRC25 = np.nanmean(df['rc25'])
# Calculate the mean average precision (mAP) for the common classes
# choose the common classes

# check if the class id is in the common classes
common_classes = df[df['class'].isin(COMMON_CATS_SCANNET_200)][:40]
# print(common_classes)
mAP_common_classes = np.nanmean(common_classes['ap'])
mAP50_common_classes = np.nanmean(common_classes['ap50'])
mAP25_common_classes = np.nanmean(common_classes['ap25'])
mRC_common_classes = np.nanmean(common_classes['rc'])
mRC50_common_classes = np.nanmean(common_classes['rc50'])
mRC25_common_classes = np.nanmean(common_classes['rc25'])

# Calculate the mean average precision (mAP) for the head classes
head_classes = df[df['class'].isin(HEAD_CATS_SCANNET_200)][:40]
mAP_head_classes = np.nanmean(head_classes['ap'])
mAP50_head_classes = np.nanmean(head_classes['ap50'])
mAP25_head_classes = np.nanmean(head_classes['ap25'])
mRC_head_classes = np.nanmean(head_classes['rc'])
mRC50_head_classes = np.nanmean(head_classes['rc50'])
mRC25_head_classes = np.nanmean(head_classes['rc25'])
# Calculate the mean average precision (mAP) for the tail classes
tail_classes = df[df['class'].isin(TAIL_CATS_SCANNET_200)]
tail_classes = pd.concat([tail_classes[:46], tail_classes[48:50]])
mAP_tail_classes = np.nanmean(tail_classes['ap'])
mAP50_tail_classes = np.nanmean(tail_classes['ap50'])
mAP25_tail_classes = np.nanmean(tail_classes['ap25'])
mRC_tail_classes = np.nanmean(tail_classes['rc'])
mRC50_tail_classes = np.nanmean(tail_classes['rc50'])
mRC25_tail_classes = np.nanmean(tail_classes['rc25'])

#current classes are head classes  tail classes  common classes all combined
current_classes = pd.concat([head_classes, tail_classes, common_classes])
# print(current_classes, current_classes['class id'][0])


# Calculate the mean average precision (mAP) for the base classes
base_classes = current_classes[current_classes['class'].isin(BASE_CLASSES_SCANNET200)]
mAP_base_classes = np.nanmean(base_classes['ap'])
mAP50_base_classes = np.nanmean(base_classes['ap50'])
mAP25_base_classes = np.nanmean(base_classes['ap25'])
mRC_base_classes = np.nanmean(base_classes['rc'])
mRC50_base_classes = np.nanmean(base_classes['rc50'])
mRC25_base_classes = np.nanmean(base_classes['rc25'])
# Calculate the mean average precision (mAP) for the novel classes
novel_classes = current_classes[current_classes['class'].isin(NOVEL_CLASSES_SCANNET200)]
mAP_novel_classes = np.nanmean(novel_classes['ap'])
mAP50_novel_classes = np.nanmean(novel_classes['ap50'])
mAP25_novel_classes = np.nanmean(novel_classes['ap25'])
mRC_novel_classes = np.nanmean(novel_classes['rc'])
mRC50_novel_classes = np.nanmean(novel_classes['rc50'])
mRC25_novel_classes = np.nanmean(novel_classes['rc25'])

# Calculate the mean average precision (mAP) for the current classes
mAP = np.nanmean(current_classes['ap'])
mAP50 = np.nanmean(current_classes['ap50'])
mAP25 = np.nanmean(current_classes['ap25'])
mRC = np.nanmean(current_classes['rc'])
mRC50 = np.nanmean(current_classes['rc50'])
mRC25 = np.nanmean(current_classes['rc25'])

print("number of each class", len(common_classes), len(head_classes), len(tail_classes), len(base_classes), len(novel_classes))
print(f"classes", f"  mAP   ", f"   mAP50   ", f"   mAP25  ", f"   mRC  ", f"   mRC50  ", f"   mRC25  ")
print(f'all    ', mAP, mAP50, mAP25, mRC, mRC50, mRC25)
print(f'head   ', mAP_head_classes, mAP50_head_classes, mAP25_head_classes, mRC_head_classes, mRC50_head_classes, mRC25_head_classes)
print(f'common ', mAP_common_classes, mAP50_common_classes, mAP25_common_classes, mRC_common_classes, mRC50_common_classes, mRC25_common_classes)
print(f'tail   ', mAP_tail_classes, mAP50_tail_classes, mAP25_tail_classes, mRC_tail_classes, mRC50_tail_classes, mRC25_tail_classes)
print(f'------------------------------------------------------------------------')
print(f'base   ', mAP_base_classes, mAP50_base_classes, mAP25_base_classes,    mRC_base_classes, mRC50_base_classes, mRC25_base_classes)
print(f'novel  ', mAP_novel_classes, mAP50_novel_classes, mAP25_novel_classes, mRC_novel_classes, mRC50_novel_classes, mRC25_novel_classes)
# Out:
# number of each class 40 40 48 31 97
# classes   mAP       mAP50       mAP25      mRC      mRC50      mRC25
# all     0.24093177827771683 0.2857485648309249 0.31472934057756563 0.4561971808949462 0.5384442847719126 0.5868876675171791
# head    0.2696240341855945 0.32526389746365025 0.3553316066472845 0.5137142241287935 0.6159359201111011 0.6695980859426324
# common  0.21344091718315653 0.24928048589955457 0.26533506530002593 0.40390013698837224 0.46699971883795416 0.49499833911598623
# tail    0.23730599006059533 0.2793237208073609 0.32038205009090476 0.44603909465020575 0.5257716049382716 0.5894290123456789
# ------------------------------------------------------------------------
# base    0.24501483984143418 0.2946270621893794 0.3296914833811825 0.47046274097444285 0.562680866744877 0.6267490427945578
# novel   0.23945597289324072 0.2825394694001583 0.30932133715457155 0.45104095436018854 0.5296840744202387 0.5724799415133072

# %%
import numpy as np
import torch
test_ar = torch.tensor([7,2,4,3,6,8,9,1,3,3,5])
unique, counts, indices = torch.unique(test_ar, sorted=False, return_counts=True, return_inverse=True)
print(unique,counts, indices)
# reverse the order
# unique = unique.flip(0)
# counts = counts.flip(0)
# print(unique, counts)
# for i in range(len(unique)):
# Out:
# tensor([5, 1, 9, 8, 6, 3, 4, 2, 7]) tensor([8, 7, 6, 5, 4, 3, 2, 1, 5, 5, 0]) tensor([1, 1, 1, 1, 1, 3, 1, 1, 1])

# %%
print("len of each scannet200 classes", len(BASE_CLASSES_SCANNET200), len(NOVEL_CLASSES_SCANNET200), len(INSTANCE_CAT_SCANNET_200), len(HEAD_CATS_SCANNET_200), len(COMMON_CATS_SCANNET_200), len(TAIL_CATS_SCANNET_200))
# Out:
# len of each scannet200 classes 51 147 198 64 68 66

# %%
import os
ss = os.listdir("/home/jie_zhenghao/Beyond-Fixed-Forms/output/mask_3d/hair dryer")

# %%
all_ss =['scene0011_00', 'scene0015_00', 'scene0019_00', 'scene0025_00', 'scene0030_00', 'scene0046_00', 'scene0050_00', 'scene0063_00', 'scene0064_00', 'scene0077_00', 'scene0081_00', 'scene0084_00', 'scene0086_00', 'scene0088_00', 'scene0095_00', 'scene0100_00', 'scene0131_00', 'scene0139_00', 'scene0146_00', 'scene0149_00', 'scene0153_00', 'scene0164_00', 'scene0169_00', 'scene0187_00', 'scene0193_00', 'scene0196_00', 'scene0203_00', 'scene0207_00', 'scene0208_00', 'scene0217_00', 'scene0221_00', 'scene0222_00', 'scene0231_00', 'scene0246_00', 'scene0249_00', 'scene0251_00', 'scene0256_00', 'scene0257_00', 'scene0277_00', 'scene0278_00', 'scene0300_00', 'scene0304_00', 'scene0307_00', 'scene0314_00', 'scene0316_00', 'scene0328_00', 'scene0329_00', 'scene0334_00', 'scene0338_00', 'scene0342_00', 'scene0343_00', 'scene0351_00', 'scene0353_00', 'scene0354_00', 'scene0355_00', 'scene0356_00', 'scene0357_00', 'scene0377_00', 'scene0378_00', 'scene0382_00', 'scene0389_00', 'scene0406_00', 'scene0412_00', 'scene0414_00', 'scene0423_00', 'scene0426_00', 'scene0427_00', 'scene0430_00', 'scene0432_00', 'scene0435_00', 'scene0441_00', 'scene0458_00', 'scene0461_00', 'scene0462_00', 'scene0474_00', 'scene0488_00', 'scene0490_00', 'scene0494_00', 'scene0496_00', 'scene0500_00', 'scene0518_00', 'scene0527_00', 'scene0535_00', 'scene0549_00', 'scene0550_00', 'scene0552_00', 'scene0553_00', 'scene0558_00', 'scene0559_00', 'scene0565_00', 'scene0568_00', 'scene0574_00', 'scene0575_00', 'scene0578_00', 'scene0580_00', 'scene0583_00', 'scene0591_00', 'scene0593_00', 'scene0595_00', 'scene0598_00', 'scene0599_00', 'scene0606_00', 'scene0607_00', 'scene0608_00', 'scene0609_00', 'scene0616_00', 'scene0618_00', 'scene0621_00', 'scene0629_00', 'scene0633_00', 'scene0643_00', 'scene0644_00', 'scene0645_00', 'scene0647_00', 'scene0648_00', 'scene0651_00', 'scene0652_00', 'scene0653_00', 'scene0655_00', 'scene0658_00', 'scene0660_00', 'scene0663_00', 'scene0664_00', 'scene0665_00', 'scene0670_00', 'scene0671_00', 'scene0678_00', 'scene0684_00', 'scene0685_00', 'scene0686_00', 'scene0689_00', 'scene0690_00', 'scene0693_00', 'scene0695_00', 'scene0696_00', 'scene0697_00', 'scene0699_00', 'scene0700_00', 'scene0701_00', 'scene0702_00', 'scene0704_00']

# %%
for s in ss:
    if s[:-4] not in all_ss:
        print(s)
# Out:
# scene0144_00.pth
