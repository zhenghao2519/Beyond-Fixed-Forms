# %%
BASE_CLASSES_SCANNET200 = [
    "chair",
    "table",
    "door",
    "couch",
    "cabinet",
    "shelf",
    "desk",
    "office chair",
    "bed",
    "sink",
    "picture",
    "window",
    "toilet",
    "bookshelf",
    "curtain",
    "armchair",
    "coffee table",
    "refrigerator",
    "kitchen cabinet",
    "counter",
    "dresser",
    "ceiling",
    "bathtub",
    "end table",
    "dining table",
    "shower curtain",
    "closet",
    "ottoman",
    "bench",
    "sofa chair",
    "file cabinet",
    "blinds",
    "container",
    "wardrobe",
    "seat",
    "column",
    "shower wall",
    "kitchen counter",
    "mini fridge",
    "shower door",
    "pillar",
    "furniture",
    "storage container",
    "closet door",
    "shower floor",
    "bathroom counter",
    "closet wall",
    "bathroom stall door",
    "bathroom cabinet",
    "folded chair",
    "mattress",
]

NOVEL_CLASSES_SCANNET200 = [
    "pillow",
    "monitor",
    "book",
    "box",
    "lamp",
    "towel",
    "clothes",
    "tv",
    "nightstand",
    "stool",
    "cushion",
    "plant",
    "keyboard",
    "bag",
    "backpack",
    "toilet paper",
    "printer",
    "tv stand",
    "whiteboard",
    "blanket",
    "trash can",
    "stairs",
    "microwave",
    "stove",
    "shoe",
    "computer tower",
    "bottle",
    "bin",
    "board",
    "washing machine",
    "mirror",
    "copier",
    "basket",
    "fan",
    "laptop",
    "shower",
    "paper",
    "person",
    "paper towel dispenser",
    "oven",
    "rack",
    "plate",
    "blackboard",
    "piano",
    "suitcase",
    "rail",
    "radiator",
    "recycling bin",
    "soap dispenser",
    "telephone",
    "bucket",
    "clock",
    "stand",
    "light",
    "laundry basket",
    "pipe",
    "clothes dryer",
    "guitar",
    "toilet paper holder",
    "speaker",
    "bicycle",
    "ladder",
    "bathroom stall",
    "cup",
    "jacket",
    "storage bin",
    "coffee maker",
    "dishwasher",
    "paper towel roll",
    "machine",
    "mat",
    "windowsill",
    "bar",
    "toaster",
    "bulletin board",
    "ironing board",
    "fireplace",
    "soap dish",
    "doorframe",
    "toilet paper dispenser",
    "fire extinguisher",
    "ball",
    "hat",
    "shower curtain rod",
    "water cooler",
    "paper cutter",
    "tray",
    "ledge",
    "toaster oven",
    "mouse",
    "toilet seat cover dispenser",
    "cart",
    "scale",
    "tissue box",
    "light switch",
    "crate",
    "power outlet",
    "decoration",
    "sign",
    "projector",
    "vacuum cleaner",
    "candle",
    "plunger",
    "stuffed animal",
    "headphones",
    "dish rack",
    "broom",
    "guitar case",
    "range hood",
    "dustpan",
    "hair dryer",
    "water bottle",
    "handicap bar",
    "purse",
    "vent",
    "water pitcher",
    "mailbox",
    "bowl",
    "paper bag",
    "alarm clock",
    "music stand",
    "projector screen",
    "divider",
    "laundry detergent",
    "object",
    "bathroom vanity",
    "laundry hamper",
    "ceiling light",
    "trash bin",
    "dumbbell",
    "stair rail",
    "tube",
    "cd case",
    "closet rod",
    "coffee kettle",
    "structure",
    "shower head",
    "keyboard piano",
    "case of water bottles",
    "coat rack",
    "storage organizer",
    "fire alarm",
    "power strip",
    "calendar",
    "poster",
    "potted plant",
    "luggage",
]

INSTANCE_CAT_SCANNET_200 = [
    "chair",
    "table",
    "door",
    "couch",
    "cabinet",
    "shelf",
    "desk",
    "office chair",
    "bed",
    "pillow",
    "sink",
    "picture",
    "window",
    "toilet",
    "bookshelf",
    "monitor",
    "curtain",
    "book",
    "armchair",
    "coffee table",
    "box",
    "refrigerator",
    "lamp",
    "kitchen cabinet",
    "towel",
    "clothes",
    "tv",
    "nightstand",
    "counter",
    "dresser",
    "stool",
    "cushion",
    "plant",
    "ceiling",
    "bathtub",
    "end table",
    "dining table",
    "keyboard",
    "bag",
    "backpack",
    "toilet paper",
    "printer",
    "tv stand",
    "whiteboard",
    "blanket",
    "shower curtain",
    "trash can",
    "closet",
    "stairs",
    "microwave",
    "stove",
    "shoe",
    "computer tower",
    "bottle",
    "bin",
    "ottoman",
    "bench",
    "board",
    "washing machine",
    "mirror",
    "copier",
    "basket",
    "sofa chair",
    "file cabinet",
    "fan",
    "laptop",
    "shower",
    "paper",
    "person",
    "paper towel dispenser",
    "oven",
    "blinds",
    "rack",
    "plate",
    "blackboard",
    "piano",
    "suitcase",
    "rail",
    "radiator",
    "recycling bin",
    "container",
    "wardrobe",
    "soap dispenser",
    "telephone",
    "bucket",
    "clock",
    "stand",
    "light",
    "laundry basket",
    "pipe",
    "clothes dryer",
    "guitar",
    "toilet paper holder",
    "seat",
    "speaker",
    "column",
    "bicycle",
    "ladder",
    "bathroom stall",
    "shower wall",
    "cup",
    "jacket",
    "storage bin",
    "coffee maker",
    "dishwasher",
    "paper towel roll",
    "machine",
    "mat",
    "windowsill",
    "bar",
    "toaster",
    "bulletin board",
    "ironing board",
    "fireplace",
    "soap dish",
    "kitchen counter",
    "doorframe",
    "toilet paper dispenser",
    "mini fridge",
    "fire extinguisher",
    "ball",
    "hat",
    "shower curtain rod",
    "water cooler",
    "paper cutter",
    "tray",
    "shower door",
    "pillar",
    "ledge",
    "toaster oven",
    "mouse",
    "toilet seat cover dispenser",
    "furniture",
    "cart",
    "storage container",
    "scale",
    "tissue box",
    "light switch",
    "crate",
    "power outlet",
    "decoration",
    "sign",
    "projector",
    "closet door",
    "vacuum cleaner",
    "candle",
    "plunger",
    "stuffed animal",
    "headphones",
    "dish rack",
    "broom",
    "guitar case",
    "range hood",
    "dustpan",
    "hair dryer",
    "water bottle",
    "handicap bar",
    "purse",
    "vent",
    "shower floor",
    "water pitcher",
    "mailbox",
    "bowl",
    "paper bag",
    "alarm clock",
    "music stand",
    "projector screen",
    "divider",
    "laundry detergent",
    "bathroom counter",
    "object",
    "bathroom vanity",
    "closet wall",
    "laundry hamper",
    "bathroom stall door",
    "ceiling light",
    "trash bin",
    "dumbbell",
    "stair rail",
    "tube",
    "bathroom cabinet",
    "cd case",
    "closet rod",
    "coffee kettle",
    "structure",
    "shower head",
    "keyboard piano",
    "case of water bottles",
    "coat rack",
    "storage organizer",
    "folded chair",
    "fire alarm",
    "power strip",
    "calendar",
    "poster",
    "potted plant",
    "luggage",
    "mattress",
]

HEAD_CATS_SCANNET_200 = [ # wall and floor removed
    "tv stand",
    "curtain",
    "blinds",
    "shower curtain",
    "bookshelf",
    "tv",
    "kitchen cabinet",
    "pillow",
    "lamp",
    "dresser",
    "monitor",
    "object",
    "ceiling",
    "board",
    "stove",
    "closet wall",
    "couch",
    "office chair",
    "kitchen counter",
    "shower",
    "closet",
    "doorframe",
    "sofa chair",
    "mailbox",
    "nightstand",
    "washing machine",
    "picture",
    "book",
    "sink",
    "recycling bin",
    "table",
    "backpack",
    "shower wall",
    "toilet",
    "copier",
    "counter",
    "stool",
    "refrigerator",
    "window",
    "file cabinet",
    "chair",
    "plant",
    "coffee table",
    "stairs",
    "armchair",
    "cabinet",
    "bathroom vanity",
    "bathroom stall",
    "mirror",
    "blackboard",
    "trash can",
    "stair rail",
    "box",
    "towel",
    "door",
    "clothes",
    "whiteboard",
    "bed",
    "bathtub",
    "desk",
    "wardrobe",
    "clothes dryer",
    "radiator",
    "shelf",
]
COMMON_CATS_SCANNET_200 = [
    "cushion",
    "end table",
    "dining table",
    "keyboard",
    "bag",
    "toilet paper",
    "printer",
    "blanket",
    "microwave",
    "shoe",
    "computer tower",
    "bottle",
    "bin",
    "ottoman",
    "bench",
    "basket",
    "fan",
    "laptop",
    "person",
    "paper towel dispenser",
    "oven",
    "rack",
    "piano",
    "suitcase",
    "rail",
    "container",
    "telephone",
    "stand",
    "light",
    "laundry basket",
    "pipe",
    "seat",
    "column",
    "bicycle",
    "ladder",
    "jacket",
    "storage bin",
    "coffee maker",
    "dishwasher",
    "machine",
    "mat",
    "windowsill",
    "bulletin board",
    "fireplace",
    "mini fridge",
    "water cooler",
    "shower door",
    "pillar",
    "ledge",
    "furniture",
    "cart",
    "decoration",
    "closet door",
    "vacuum cleaner",
    "dish rack",
    "range hood",
    "projector screen",
    "divider",
    "bathroom counter",
    "laundry hamper",
    "bathroom stall door",
    "ceiling light",
    "trash bin",
    "bathroom cabinet",
    "structure",
    "storage organizer",
    "potted plant",
    "mattress",
]
TAIL_CATS_SCANNET_200 = [
    "paper",
    "plate",
    "soap dispenser",
    "bucket",
    "clock",
    "guitar",
    "toilet paper holder",
    "speaker",
    "cup",
    "paper towel roll",
    "bar",
    "toaster",
    "ironing board",
    "soap dish",
    "toilet paper dispenser",
    "fire extinguisher",
    "ball",
    "hat",
    "shower curtain rod",
    "paper cutter",
    "tray",
    "toaster oven",
    "mouse",
    "toilet seat cover dispenser",
    "storage container",
    "scale",
    "tissue box",
    "light switch",
    "crate",
    "power outlet",
    "sign",
    "projector",
    "candle",
    "plunger",
    "stuffed animal",
    "headphones",
    "broom",
    "guitar case",
    "dustpan",
    "hair dryer",
    "water bottle",
    "handicap bar",
    "purse",
    "vent",
    "shower floor",
    "water pitcher",
    "bowl",
    "paper bag",
    "alarm clock",
    "music stand",
    "laundry detergent",
    "dumbbell",
    "tube",
    "cd case",
    "closet rod",
    "coffee kettle",
    "shower head",
    "keyboard piano",
    "case of water bottles",
    "coat rack",
    "folded chair",
    "fire alarm",
    "power strip",
    "calendar",
    "poster",
    "luggage",
]

# %%
import pandas as pd
import numpy as np
import sys

# # remove the comma at end of each line
file_path = 'stage1_new_refine_overall_results.csv'
# # file_path = "/home/jie_zhenghao/Beyond-Fixed-Forms/evaluation/eval_results/for_comparision/open3dis_hct_result_00_142.csv"
# with open(file_path, "r") as f:
#     lines = f.readlines()
# with open(file_path, "w") as f:
#     for line in lines:
#         if line.strip("\n")[-1] == ",":
#             f.write(line.strip("\n")[:-1] + "\n")
#         else:
#             f.write(line)

# Load the overall_results.csv file
df = pd.read_csv(file_path)

# %%
df.keys()
df
# Out:
#               class        ap      ap50      ap25        rc      rc50  \
# 0          tv stand  0.473367  0.501280  0.501379  0.944444  1.000000
# 1           curtain  0.347057  0.429915  0.498103  0.675926  0.833333
# 2            blinds  0.000000  0.000000  0.250904  0.000000  0.000000
# 3    shower curtain  0.434474  0.511811  0.512793  0.851852  1.000000
# 4         bookshelf  0.250350  0.392011  0.498072  0.492593  0.766667
# ..              ...       ...       ...       ...       ...       ...
# 103            vent       NaN       NaN       NaN       NaN       NaN
# 104    shower floor  0.502050  0.502203  0.502525  1.000000  1.000000
# 105   water pitcher  0.391684  0.503650  0.504032  0.777778  1.000000
# 106     alarm clock       NaN       NaN       NaN       NaN       NaN
# 107     music stand       NaN       NaN       NaN       NaN       NaN
#
#         rc25
# 0    1.000000
# 1    0.958333
# 2    0.500000
# 3    1.000000
# 4    0.966667
# ..        ...
# 103       NaN
# 104  1.000000
# 105  1.000000
# 106       NaN
# 107       NaN
#
# [108 rows x 7 columns]

# %%
print(df['class'][0])
print(df['ap'][0])
print(df['ap50'][0])
print(df['ap25'][0])
print(len(df['class']))
# print("power outlet" in TAIL_CATS_SCANNET_200)
# df['class id'].keys()[89], df['class id'].keys()[89] in (TAIL_CATS_SCANNET_200)
# Out:
# tv stand
# 0.4733672449898606
# 0.501280409731114
# 0.5013793103448276
# 108

# %%
np.asarray(df['ap'])
# Out:
# array([0.47336724, 0.34705693, 0.        , 0.43447421, 0.2503502 ,
#        0.4461637 , 0.3019228 , 0.37105148, 0.3743803 , 0.29540849,
#        0.4057633 , 0.07019183, 0.28654528, 0.07831027, 0.16188861,
#        0.09279816, 0.37728334, 0.48358403, 0.30174186, 0.        ,
#        0.02784603, 0.16630077, 0.4623589 , 0.31891993, 0.29545561,
#        0.30466294, 0.16136074, 0.0150083 , 0.35818211, 0.38709598,
#        0.        , 0.28546214, 0.        , 0.40308503, 0.3559668 ,
#        0.32008429, 0.47768104, 0.18967163, 0.38141314, 0.26643463,
#        0.1325353 , 0.39682144, 0.16680622, 0.36795881, 0.20776508,
#               nan, 0.33211995, 0.32099196, 0.09268026, 0.47052303,
#        0.39113808, 0.16785633, 0.44638099, 0.39723615, 0.22861393,
#        0.16751376, 0.30058856, 0.        , 0.30253118, 0.42842626,
#        0.23078527, 0.25096418, 0.46266212, 0.24934275, 0.45748079,
#        0.39716848, 0.        ,        nan, 0.26533446, 0.31010849,
#        0.2002235 , 0.        , 0.22284499, 0.08415005, 0.40523016,
#        0.50802684, 0.50706962, 0.44716246, 0.11134214, 0.30427424,
#        0.12556378, 0.50761778,        nan, 0.1822003 ,        nan,
#        0.50433522, 0.29087924,        nan, 0.22263324, 0.        ,
#        0.16230867, 0.39102203,        nan, 0.        ,        nan,
#        0.        , 0.16725989,        nan, 0.        , 0.40833333,
#        0.50417572,        nan,        nan,        nan, 0.50204968,
#        0.39168408,        nan,        nan])

# %%
# Calculate the mean average precision (mAP)
mAP = np.nanmean(df['ap'])
mAP50 = np.nanmean(df['ap50'])
mAP25 = np.nanmean(df['ap25']) 
# Calculate the mean average precision (mAP) for the common classes
# choose the common classes

# check if the class id is in the common classes
common_classes = df[df['class'].isin(COMMON_CATS_SCANNET_200)]
# print(common_classes)
mAP_common_classes = np.nanmean(common_classes['ap'])
mAP50_common_classes = np.nanmean(common_classes['ap50'])
mAP25_common_classes = np.nanmean(common_classes['ap25'])
# Calculate the mean average precision (mAP) for the head classes
head_classes = df[df['class'].isin(HEAD_CATS_SCANNET_200)]
mAP_head_classes = np.nanmean(head_classes['ap'])
mAP50_head_classes = np.nanmean(head_classes['ap50'])
mAP25_head_classes = np.nanmean(head_classes['ap25'])
# Calculate the mean average precision (mAP) for the tail classes
tail_classes = df[df['class'].isin(TAIL_CATS_SCANNET_200)]
mAP_tail_classes = np.nanmean(tail_classes['ap'])
mAP50_tail_classes = np.nanmean(tail_classes['ap50'])
mAP25_tail_classes = np.nanmean(tail_classes['ap25'])

current_classes = pd.concat([head_classes, tail_classes, common_classes])

# Calculate the mean average precision (mAP) for the base classes
base_classes = current_classes[current_classes['class'].isin(BASE_CLASSES_SCANNET200)]
mAP_base_classes = np.nanmean(base_classes['ap'])
mAP50_base_classes = np.nanmean(base_classes['ap50'])
mAP25_base_classes = np.nanmean(base_classes['ap25'])
# Calculate the mean average precision (mAP) for the novel classes
novel_classes = current_classes[current_classes['class'].isin(NOVEL_CLASSES_SCANNET200)]
mAP_novel_classes = np.nanmean(novel_classes['ap'])
mAP50_novel_classes = np.nanmean(novel_classes['ap50'])
mAP25_novel_classes = np.nanmean(novel_classes['ap25'])

print("number of each class", len(common_classes), len(head_classes), len(tail_classes), len(base_classes), len(novel_classes))
print(f"classes", f"  mAP   ", f"   mAP50   ", f"   mAP25  ")
print(f'all    ', mAP, mAP50, mAP25)
print(f'head   ', mAP_head_classes, mAP50_head_classes, mAP25_head_classes)
print(f'common ', mAP_common_classes, mAP50_common_classes, mAP25_common_classes)
print(f'tail   ', mAP_tail_classes, mAP50_tail_classes, mAP25_tail_classes)
print(f'------------------------------------------------------------------------')
print(f'base   ', mAP_base_classes, mAP50_base_classes, mAP25_base_classes)
print(f'novel  ', mAP_novel_classes, mAP50_novel_classes, mAP25_novel_classes)
# Out:
# number of each class 30 30 48 22 86
# classes   mAP       mAP50       mAP25
# all     0.2718104509920586 0.3326145258210206 0.39765081665090934
# head    0.26831577801665646 0.34834545480008855 0.40656657982698596
# common  0.27580296462329945 0.3269805416181529 0.39966680848956787
# tail    0.271506486935283 0.32404390561299645 0.3885970205785927
# ------------------------------------------------------------------------
# base    0.27198393068280363 0.34363305640638026 0.43586352744042084
# novel   0.27176122026900934 0.32948764551977 0.3868066689944264

# %%
class_order = df['class']
class_order
# Out:
# 0            tv stand
# 1             curtain
# 2              blinds
# 3      shower curtain
# 4           bookshelf
#             ...
# 103              vent
# 104      shower floor
# 105     water pitcher
# 106       alarm clock
# 107       music stand
# Name: class, Length: 108, dtype: object

# %%
# Load the overall_results.csv file
df = pd.read_csv('/home/jie_zhenghao/Beyond-Fixed-Forms/evaluation/eval_results/for_comparision/true_open3dis_resutl.csv')
open3dis_class_num = 30
print(df['class'].count())
# Out:
# 198

# %%
"""order open3dis results into HEAD, COMMON, TAIL order"""
# head_classes = df[df['class'].isin(HEAD_CATS_SCANNET_200)]
# head_classes
# ordered_head_classes = []
# # make head classes in the same order like HEAD_CATS_SCANNET_200
# for i in range(len(HEAD_CATS_SCANNET_200)):
#     if HEAD_CATS_SCANNET_200[i] in head_classes['class'].values:
#         ordered_head_classes.append(head_classes[head_classes['class'] == HEAD_CATS_SCANNET_200[i]])
# ordered_head_classes = pd.concat(ordered_head_classes)
# ordered_head_classes
        

# common_classes = df[df['class'].isin(COMMON_CATS_SCANNET_200)]
# common_classes
# ordered_common_classes = []
# # make head classes in the same order like HEAD_CATS_SCANNET_200
# for i in range(len(COMMON_CATS_SCANNET_200)):
#     if COMMON_CATS_SCANNET_200[i] in common_classes['class'].values:
#         ordered_common_classes.append(common_classes[common_classes['class'] == COMMON_CATS_SCANNET_200[i]])
# ordered_common_classes = pd.concat(ordered_common_classes)
# ordered_common_classes

# tail_classes = df[df['class'].isin(TAIL_CATS_SCANNET_200)]
# tail_classes
# ordered_tail_classes = []
# # make head classes in the same order like HEAD_CATS_SCANNET_200
# for i in range(len(TAIL_CATS_SCANNET_200)):
#     if TAIL_CATS_SCANNET_200[i] in tail_classes['class'].values:
#         ordered_tail_classes.append(tail_classes[tail_classes['class'] == TAIL_CATS_SCANNET_200[i]])
# ordered_tail_classes = pd.concat(ordered_tail_classes)
# ordered_tail_classes

# ordered_classes = pd.concat([ordered_head_classes, ordered_tail_classes, ordered_common_classes])

# # replace nan values with -1
# ordered_classes = ordered_classes.fillna(-1)

# # save the ordered classes to a csv file, which also contains nan values
# ordered_classes.to_csv('ordered_classes.csv', index=False)

# %%
print(df['class'][0])
print(df['ap'][0])
print(df['ap50'][0])
print(df['ap25'][0])
print(len(df['class']))
# Out:
# chair
# 0.4098739715189641
# 0.463581790987933
# 0.4850300033328658
# 198

# %%
# Calculate the mean average precision (mAP)
mAP = np.nanmean(df['ap'])
mAP50 = np.nanmean(df['ap50'])
mAP25 = np.nanmean(df['ap25']) 
# Calculate the mean average precision (mAP) for the common classes
# choose the common classes

# check if the class id is in the common classes
common_classes = df[df['class'].isin(COMMON_CATS_SCANNET_200)][:open3dis_class_num]
# print(common_classes)
mAP_common_classes = np.nanmean(common_classes['ap'])
mAP50_common_classes = np.nanmean(common_classes['ap50'])
mAP25_common_classes = np.nanmean(common_classes['ap25'])
# Calculate the mean average precision (mAP) for the head classes
head_classes = df[df['class'].isin(HEAD_CATS_SCANNET_200)][:open3dis_class_num]
mAP_head_classes = np.nanmean(head_classes['ap'])
mAP50_head_classes = np.nanmean(head_classes['ap50'])
mAP25_head_classes = np.nanmean(head_classes['ap25'])
# Calculate the mean average precision (mAP) for the tail classes
tail_classes = df[df['class'].isin(TAIL_CATS_SCANNET_200)]
tail_classes = pd.concat([tail_classes[:46], tail_classes[48:50]])
mAP_tail_classes = np.nanmean(tail_classes['ap'])
mAP50_tail_classes = np.nanmean(tail_classes['ap50'])
mAP25_tail_classes = np.nanmean(tail_classes['ap25'])

#current classes are head classes  tail classes  common classes all combined
current_classes = pd.concat([head_classes, tail_classes, common_classes])
# print(current_classes, current_classes['class id'][0])


# Calculate the mean average precision (mAP) for the base classes
base_classes = current_classes[current_classes['class'].isin(BASE_CLASSES_SCANNET200)]
mAP_base_classes = np.nanmean(base_classes['ap'])
mAP50_base_classes = np.nanmean(base_classes['ap50'])
mAP25_base_classes = np.nanmean(base_classes['ap25'])
# Calculate the mean average precision (mAP) for the novel classes
novel_classes = current_classes[current_classes['class'].isin(NOVEL_CLASSES_SCANNET200)]
mAP_novel_classes = np.nanmean(novel_classes['ap'])
mAP50_novel_classes = np.nanmean(novel_classes['ap50'])
mAP25_novel_classes = np.nanmean(novel_classes['ap25'])

print("number of each class", len(common_classes), len(head_classes), len(tail_classes), len(base_classes), len(novel_classes))
print(f"classes", f"  mAP   ", f"   mAP50   ", f"   mAP25  ")
print(f'all    ', mAP, mAP50, mAP25)
print(f'head   ', mAP_head_classes, mAP50_head_classes, mAP25_head_classes)
print(f'common ', mAP_common_classes, mAP50_common_classes, mAP25_common_classes)
print(f'tail   ', mAP_tail_classes, mAP50_tail_classes, mAP25_tail_classes)
print(f'------------------------------------------------------------------------')
print(f'base   ', mAP_base_classes, mAP50_base_classes, mAP25_base_classes)
print(f'novel  ', mAP_novel_classes, mAP50_novel_classes, mAP25_novel_classes)
# Out:
# number of each class 30 30 48 28 80
# classes   mAP       mAP50       mAP25
# all     0.2419775720042807 0.2947219933448015 0.332031695390922
# head    0.2823428691996623 0.3399414080840554 0.3655852626012249
# common  0.22993154095901708 0.27352006105448184 0.28701189833046475
# tail    0.23730599006059533 0.2793237208073609 0.32038205009090476
# ------------------------------------------------------------------------
# base    0.2775128302173118 0.32577830826459525 0.3493497337496344
# novel   0.23806573514875554 0.28514652410327285 0.31459138120077457

# %%
import numpy as np
import torch
test_ar = torch.tensor([7,2,4,3,6,8,9,1,3,3,5])
unique, counts, indices = torch.unique(test_ar, sorted=False, return_counts=True, return_inverse=True)
print(unique,counts, indices)
# reverse the order
# unique = unique.flip(0)
# counts = counts.flip(0)
# print(unique, counts)
# for i in range(len(unique)):
# Out:
# tensor([5, 1, 9, 8, 6, 3, 4, 2, 7]) tensor([8, 7, 6, 5, 4, 3, 2, 1, 5, 5, 0]) tensor([1, 1, 1, 1, 1, 3, 1, 1, 1])

# %%
print("len of each scannet200 classes", len(BASE_CLASSES_SCANNET200), len(NOVEL_CLASSES_SCANNET200), len(INSTANCE_CAT_SCANNET_200), len(HEAD_CATS_SCANNET_200), len(COMMON_CATS_SCANNET_200), len(TAIL_CATS_SCANNET_200))
# Out:
# len of each scannet200 classes 51 147 198 64 68 66

# %%
import os
ss = os.listdir("/home/jie_zhenghao/Beyond-Fixed-Forms/output/mask_3d/hair dryer")

# %%
all_ss =['scene0011_00', 'scene0015_00', 'scene0019_00', 'scene0025_00', 'scene0030_00', 'scene0046_00', 'scene0050_00', 'scene0063_00', 'scene0064_00', 'scene0077_00', 'scene0081_00', 'scene0084_00', 'scene0086_00', 'scene0088_00', 'scene0095_00', 'scene0100_00', 'scene0131_00', 'scene0139_00', 'scene0146_00', 'scene0149_00', 'scene0153_00', 'scene0164_00', 'scene0169_00', 'scene0187_00', 'scene0193_00', 'scene0196_00', 'scene0203_00', 'scene0207_00', 'scene0208_00', 'scene0217_00', 'scene0221_00', 'scene0222_00', 'scene0231_00', 'scene0246_00', 'scene0249_00', 'scene0251_00', 'scene0256_00', 'scene0257_00', 'scene0277_00', 'scene0278_00', 'scene0300_00', 'scene0304_00', 'scene0307_00', 'scene0314_00', 'scene0316_00', 'scene0328_00', 'scene0329_00', 'scene0334_00', 'scene0338_00', 'scene0342_00', 'scene0343_00', 'scene0351_00', 'scene0353_00', 'scene0354_00', 'scene0355_00', 'scene0356_00', 'scene0357_00', 'scene0377_00', 'scene0378_00', 'scene0382_00', 'scene0389_00', 'scene0406_00', 'scene0412_00', 'scene0414_00', 'scene0423_00', 'scene0426_00', 'scene0427_00', 'scene0430_00', 'scene0432_00', 'scene0435_00', 'scene0441_00', 'scene0458_00', 'scene0461_00', 'scene0462_00', 'scene0474_00', 'scene0488_00', 'scene0490_00', 'scene0494_00', 'scene0496_00', 'scene0500_00', 'scene0518_00', 'scene0527_00', 'scene0535_00', 'scene0549_00', 'scene0550_00', 'scene0552_00', 'scene0553_00', 'scene0558_00', 'scene0559_00', 'scene0565_00', 'scene0568_00', 'scene0574_00', 'scene0575_00', 'scene0578_00', 'scene0580_00', 'scene0583_00', 'scene0591_00', 'scene0593_00', 'scene0595_00', 'scene0598_00', 'scene0599_00', 'scene0606_00', 'scene0607_00', 'scene0608_00', 'scene0609_00', 'scene0616_00', 'scene0618_00', 'scene0621_00', 'scene0629_00', 'scene0633_00', 'scene0643_00', 'scene0644_00', 'scene0645_00', 'scene0647_00', 'scene0648_00', 'scene0651_00', 'scene0652_00', 'scene0653_00', 'scene0655_00', 'scene0658_00', 'scene0660_00', 'scene0663_00', 'scene0664_00', 'scene0665_00', 'scene0670_00', 'scene0671_00', 'scene0678_00', 'scene0684_00', 'scene0685_00', 'scene0686_00', 'scene0689_00', 'scene0690_00', 'scene0693_00', 'scene0695_00', 'scene0696_00', 'scene0697_00', 'scene0699_00', 'scene0700_00', 'scene0701_00', 'scene0702_00', 'scene0704_00']

# %%
for s in ss:
    if s[:-4] not in all_ss:
        print(s)
# Out:
# scene0144_00.pth
